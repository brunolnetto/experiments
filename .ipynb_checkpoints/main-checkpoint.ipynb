# %%
# Libraries import
from sklearn import linear_model

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Water falling initial pixel coordinates
x0 = 253
y0 = 561

# %%
# Collected data
df_ = pd.read_csv('rain.csv')

# Data normalization
max_px = max(df_['px'])
max_py = max(df_['py'])

df['px'] = df_['px']/max_px
df['py'] = df_['py']/max_py

# Data Interpolation
n = 6;

df['1'] = 1

fields = ['1', 'px']

for i in range(2, n+1):
    field = 'px**' + str(i)
    fields.append(field)
    
    df[field] = df['px']**i

fields.append('py')

df = df[fields]

df_np = df.to_numpy()

x = df_np[:, 0:n+1]
y = df_np[:, n+1:n+2]

# %%
regr = linear_model.LinearRegression()
predictor = regr.fit(x, y)
df_np = df.to_numpy()

# %%
dx = 0.01

vals = np.arange(0, 1, dx)

vecs = []


for i in range(0, n+1):
    vec = vals**i
    vecs.append(vec)

X = np.column_stack(tuple(vecs))
Y = regr.predict(X)

# %%
px = df['px'].to_numpy()
py = df['py'].to_numpy()

x_orig = x0 + px*max_px
y_orig = y0 + py*max_py

x_pred = x0 + vals*max_px
y_pred = y0 + Y*max_py

plt.figure()
plt.plot(x_orig, y_orig, '*')
plt.plot(x_pred, y_pred)

plt.axis('equal')
# Out:
# (239.437, 537.823, 522.1501594077168, 1259.02242481824)

# %%
regr.coef_
# Out:
# array([[  0.        ,  -0.51762119,   8.9254419 , -36.38276963,
#          75.41930423, -72.30392438,  25.89368627]])

# %%
img = plt.imread('rain.jpg')

plt.figure()
plt.plot(x_orig, y_orig, '*')
plt.plot(x_pred, y_pred)

plt.imshow(img)

plt.savefig('rain_interp.eps')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-295-f9aa190c1156> in <module>()
#       7 plt.imshow(img)
#       8
# ----> 9 plt.savefig('rain_interp.jpg')
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in savefig(*args, **kwargs)
#     693 def savefig(*args, **kwargs):
#     694     fig = gcf()
# --> 695     res = fig.savefig(*args, **kwargs)
#     696     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     697     return res
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/figure.pyc in savefig(self, fname, **kwargs)
#    2060             self.set_frameon(frameon)
#    2061
# -> 2062         self.canvas.print_figure(fname, **kwargs)
#    2063
#    2064         if frameon:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2171
#    2172         # get canvas object and print method for format
# -> 2173         canvas = self._get_output_canvas(format)
#    2174         print_method = getattr(canvas, 'print_%s' % format)
#    2175
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/backend_bases.pyc in _get_output_canvas(self, fmt)
#    2103         raise ValueError(
#    2104             "Format {!r} is not supported (supported formats: {})"
# -> 2105             .format(fmt, ", ".join(sorted(self.get_supported_filetypes()))))
#    2106
#    2107     def print_figure(self, filename, dpi=None, facecolor=None, edgecolor=None,
#
# ValueError: Format 'jpg' is not supported (supported formats: eps, pdf, pgf, png, ps, raw, rgba, svg, svgz)
